# %%
import pandas as pd

# %%
df_500 = pd.read_csv('data/500_Cities__Local_Data_for_Better_Health__2019_release_20240416.csv')
df_locations = pd.read_csv('data/locations.csv')

# %%
df_500.head()
# Out:
#    Year StateAbbr   StateDesc   CityName GeographicLevel DataSource  \
# 0  2017        CA  California  Hawthorne    Census Tract      BRFSS
# 1  2017        CA  California  Hawthorne            City      BRFSS
# 2  2017        CA  California    Hayward            City      BRFSS
# 3  2017        CA  California    Hayward            City      BRFSS
# 4  2017        CA  California      Hemet            City      BRFSS
#
#               Category             UniqueID  \
# 0      Health Outcomes  0632548-06037602504
# 1  Unhealthy Behaviors              0632548
# 2      Health Outcomes              0633000
# 3  Unhealthy Behaviors              0633000
# 4           Prevention              0633182
#
#                                              Measure Data_Value_Unit  ...  \
# 0             Arthritis among adults aged >=18 Years               %  ...
# 1       Current smoking among adults aged >=18 Years               %  ...
# ...

# %%
df_500["Year"].value_counts()
# Out:
# Year
# 2017    580087
# 2016    230016
# Name: count, dtype: int64

# %%
df_500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810103 entries, 0 to 810102
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Year                        810103 non-null  int64
#  1   StateAbbr                   810103 non-null  object
#  2   StateDesc                   810103 non-null  object
#  3   CityName                    810047 non-null  object
#  4   GeographicLevel             810103 non-null  object
#  5   DataSource                  810103 non-null  object
#  6   Category                    810103 non-null  object
#  7   UniqueID                    810103 non-null  object
#  8   Measure                     810103 non-null  object
#  9   Data_Value_Unit             810103 non-null  object
#  10  DataValueTypeID             810103 non-null  object
#  11  Data_Value_Type             810103 non-null  object
#  12  Data_Value                  787311 non-null  float64
# ...

# %%
df_500.nunique().reset_index().sort_values(0, ascending=False)
# Out:
#                          index      0
# 7                     UniqueID  28505
# 18                 GeoLocation  28504
# 22                   TractFIPS  27648
# 17             PopulationCount   8050
# 14       High_Confidence_Limit    955
# 12                  Data_Value    946
# 13        Low_Confidence_Limit    937
# 21                    CityFIPS    500
# 3                     CityName    474
# 1                    StateAbbr     52
# 2                    StateDesc     52
# 20                   MeasureId     28
# 23         Short_Question_Text     28
# 8                      Measure     28
# 15  Data_Value_Footnote_Symbol      3
# 16         Data_Value_Footnote      3
# 19                  CategoryID      3
# 6                     Category      3
# 4              GeographicLevel      3
# 11             Data_Value_Type      2
# 10             DataValueTypeID      2
# 0                         Year      2
# 9              Data_Value_Unit      1
# 5                   DataSource      1

# %%
df_500['Year'].value_counts()
# Out:
# Year
# 2017    580087
# 2016    230016
# Name: count, dtype: int64

# %%
df_500[['UniqueID', 'GeoLocation', 'TractFIPS', 'CityFIPS', 'StateAbbr', 'CityName']]
# Out:
#                    UniqueID                      GeoLocation     TractFIPS  \
# 0       0632548-06037602504   (33.905547923, -118.337332298)  6.037603e+09
# 1                   0632548   (33.914667701, -118.347667728)           NaN
# 2                   0633000  (37.6329591551, -122.077051051)           NaN
# 3                   0633000  (37.6329591551, -122.077051051)           NaN
# 4                   0633182  (33.7352277311, -116.994605005)           NaN
# ...                     ...                              ...           ...
# 810098  5548000-55025000202  (43.0683437287, -89.4935639435)  5.502500e+10
# 810099  5370000-53053061900  (47.2276735186, -122.434170835)  5.305306e+10
# 810100  5374060-53011041331  (45.6495869118, -122.552061838)  5.301104e+10
# 810101  5502375-55087010200  (44.2675274909, -88.4261164976)  5.508701e+10
# 810102  5370000-53053072310  (47.2421261808, -122.539866781)  5.305307e+10
#
#          CityFIPS StateAbbr   CityName
# ...

# %%
df_locations.head()
# Out:
#    Unnamed: 0             uniqueid stateabbr    cityname geographiclevel  \
# 0        6325              0107000        AL  Birmingham            City
# 1       40098  0107000-01073000100        AL  Birmingham    Census Tract
# 2        2125  0107000-01073000300        AL  Birmingham    Census Tract
# 3       20523  0107000-01073000400        AL  Birmingham    Census Tract
# 4        1727  0107000-01073000500        AL  Birmingham    Census Tract
#
#       tractfips  cityfips statedesc   latitude  longitude
# 0           NaN  107000.0   Alabama -86.798817  33.527566
# 1  1.073000e+09  107000.0   Alabama -86.722832  33.579433
# 2  1.073000e+09  107000.0   Alabama -86.752434  33.542821
# 3  1.073000e+09  107000.0   Alabama -86.764047  33.563245
# 4  1.073000e+09  107000.0   Alabama -86.774913  33.544240

# %%
df_locations[df_locations['cityname']=='Birmingham']['tractfips'][1]
# Out:
# 1073000100.0

# %%
df_500[df_500['CityName']=='Birmingham']
# Out:
#        Year StateAbbr StateDesc    CityName GeographicLevel DataSource  \
# 1264   2016        AL   Alabama  Birmingham    Census Tract      BRFSS
# 1300   2017        AL   Alabama  Birmingham    Census Tract      BRFSS
# 1341   2017        AL   Alabama  Birmingham    Census Tract      BRFSS
# 1385   2017        AL   Alabama  Birmingham    Census Tract      BRFSS
# 1414   2017        AL   Alabama  Birmingham    Census Tract      BRFSS
# ...     ...       ...       ...         ...             ...        ...
# 84744  2017        AL   Alabama  Birmingham    Census Tract      BRFSS
# 84746  2016        AL   Alabama  Birmingham    Census Tract      BRFSS
# 84747  2017        AL   Alabama  Birmingham    Census Tract      BRFSS
# 84755  2017        AL   Alabama  Birmingham    Census Tract      BRFSS
# 84758  2016        AL   Alabama  Birmingham    Census Tract      BRFSS
#
#                   Category             UniqueID  \
# 1264            Prevention  0107000-01073001400
# ...
