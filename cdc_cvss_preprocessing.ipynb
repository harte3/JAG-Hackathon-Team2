# %%
import pandas as pd

# %%
df_cdc = pd.read_csv('data/cdc/Underlying Cause of Death, 2018-2021, Single Race (version 1).csv')

# %%
df_cdc.drop('Notes', axis=1, inplace=True)
df_cdc.head()
# Out:
#                County  County Code                       Drug/Alcohol Induced  \
# 0  Autauga County, AL         1001                        Drug-induced causes
# 1  Autauga County, AL         1001                     Alcohol-induced causes
# 2  Autauga County, AL         1001  All other non-drug and non-alcohol causes
# 3  Baldwin County, AL         1003                        Drug-induced causes
# 4  Baldwin County, AL         1003                        Drug-induced causes
#
#   Drug/Alcohol Induced Code  \
# 0                         D
# 1                         A
# 2                         O
# 3                         D
# 4                         D
#
#                           Drug/Alcohol Induced Cause  \
# 0  Drug poisonings (overdose) Unintentional (X40-...
# 1                   All other alcohol-induced causes
# 2          All other non-drug and non-alcohol causes
# 3  Drug poisonings (overdose) Unintentional (X40-...
# 4       Drug poisonings (overdose) Suicide (X60-X64)
#
#   Drug/Alcohol Induced Cause Code  Deaths  Population  Crude Rate   pct_tot  \
# 0                              D1      20      226710         8.8  0.000088
# 1                              A9      16      226710  Unreliable  0.000071
# 2                              O9    2398      226710      1057.7  0.010577
# 3                              D1     185      909837        20.3  0.000203
# 4                              D2      17      909837  Unreliable  0.000019
#
#        Years
# 0  2018-2021
# 1  2018-2021
# 2  2018-2021
# 3  2018-2021
# 4  2018-2021

# %%
df_cdc.shape
# Out:
# (8244, 11)

# %%
df_cdc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8244 entries, 0 to 8243
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   County                           8244 non-null   object
#  1   County Code                      8244 non-null   int64
#  2   Drug/Alcohol Induced             8244 non-null   object
#  3   Drug/Alcohol Induced Code        8244 non-null   object
#  4   Drug/Alcohol Induced Cause       8244 non-null   object
#  5   Drug/Alcohol Induced Cause Code  8244 non-null   object
#  6   Deaths                           8244 non-null   int64
#  7   Population                       8244 non-null   int64
#  8   Crude Rate                       8244 non-null   object
#  9   pct_tot                          8244 non-null   float64
#  10  Years                            8244 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 708.6+ KB

# %%
total = df_cdc.groupby(['County']).sum().reset_index()
total
# Out:
#                     County  County Code  \
# 0     Abbeville County, SC       135003
# 1        Acadia Parish, LA        88004
# 2      Accomack County, VA       153003
# 3           Ada County, ID       112007
# 4         Adair County, IA        19001
# ...                    ...          ...
# 3134       Yuma County, AZ        16108
# 3135       Yuma County, CO         8125
# 3136     Zapata County, TX        48505
# 3137     Zavala County, TX        48507
# 3138    Ziebach County, SD        92274
#
#                                    Drug/Alcohol Induced  \
# 0     Drug-induced causesAlcohol-induced causesAll o...
# 1     Drug-induced causesDrug-induced causesAlcohol-...
# 2     Drug-induced causesAlcohol-induced causesAll o...
# 3     Drug-induced causesDrug-induced causesDrug-ind...
# 4             All other non-drug and non-alcohol causes
# ...                                                 ...
# 3134  Drug-induced causesDrug-induced causesAlcohol-...
# 3135          All other non-drug and non-alcohol causes
# 3136          All other non-drug and non-alcohol causes
# 3137          All other non-drug and non-alcohol causes
# 3138  Alcohol-induced causesAll other non-drug and n...
#
#      Drug/Alcohol Induced Code  \
# 0                          DAO
# 1                         DDAO
# 2                          DAO
# 3                      DDDDAAO
# 4                            O
# ...                        ...
# 3134                      DDAO
# 3135                         O
# 3136                         O
# 3137                         O
# 3138                        AO
#
#                              Drug/Alcohol Induced Cause  \
# 0     Drug poisonings (overdose) Unintentional (X40-...
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2     Drug poisonings (overdose) Unintentional (X40-...
# 3     Drug poisonings (overdose) Unintentional (X40-...
# 4             All other non-drug and non-alcohol causes
# ...                                                 ...
# 3134  Drug poisonings (overdose) Unintentional (X40-...
# 3135          All other non-drug and non-alcohol causes
# 3136          All other non-drug and non-alcohol causes
# 3137          All other non-drug and non-alcohol causes
# 3138  All other alcohol-induced causesAll other non-...
#
#      Drug/Alcohol Induced Cause Code  Deaths  Population  \
# 0                             D1A9O9    1415      293313
# 1                           D1D4A9O9    3169      973764
# 2                             D1A9O9    1981      390636
# 3                     D1D2D4D9A1A9O9   14385    13705181
# 4                                 O9     432       28815
# ...                              ...     ...         ...
# 3134                        D1D2A9O9    7924     3402916
# 3135                              O9     403       40027
# 3136                              O9     462       56449
# 3137                              O9     521       45197
# 3138                            A9O9      99       21068
#
#                                           Crude Rate   pct_tot  \
# 0                               22.5Unreliable1405.3  0.014473
# 1                     Unreliable18.5Unreliable1268.1  0.013018
# 2                                     18.420.71482.2  0.015214
# 3     14.12.1UnreliableUnreliableUnreliable14.9701.9  0.007347
# 4                                             1499.2  0.014992
# ...                                              ...       ...
# 3134                         21.2Unreliable10.6897.9  0.009314
# 3135                                          1006.8  0.010068
# 3136                                           818.4  0.008184
# 3137                                          1152.7  0.011527
# 3138                                 Unreliable835.4  0.009398
#
#                                                   Years
# 0                           2018-20212018-20212018-2021
# 1                  2018-20212018-20212018-20212018-2021
# 2                           2018-20212018-20212018-2021
# 3     2018-20212018-20212018-20212018-20212018-20212...
# 4                                             2018-2021
# ...                                                 ...
# 3134               2018-20212018-20212018-20212018-2021
# 3135                                          2018-2021
# 3136                                          2018-2021
# 3137                                          2018-2021
# 3138                                 2018-20212018-2021
#
# [3139 rows x 11 columns]

# %%
cdc_main = total[["County", "Deaths", "Population", "pct_tot"]]
cdc_main["Years"] = "2018-2021"
cdc_main
# Out:
# <ipython-input-7-55f920019d60>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdc_main["Years"] = "2018-2021"
#                     County  Deaths  Population   pct_tot      Years
# 0     Abbeville County, SC    1415      293313  0.014473  2018-2021
# 1        Acadia Parish, LA    3169      973764  0.013018  2018-2021
# 2      Accomack County, VA    1981      390636  0.015214  2018-2021
# 3           Ada County, ID   14385    13705181  0.007347  2018-2021
# 4         Adair County, IA     432       28815  0.014992  2018-2021
# ...                    ...     ...         ...       ...        ...
# 3134       Yuma County, AZ    7924     3402916  0.009314  2018-2021
# 3135       Yuma County, CO     403       40027  0.010068  2018-2021
# 3136     Zapata County, TX     462       56449  0.008184  2018-2021
# 3137     Zavala County, TX     521       45197  0.011527  2018-2021
# 3138    Ziebach County, SD      99       21068  0.009398  2018-2021
#
# [3139 rows x 5 columns]

# %%
1415/293313
# Out:
# 0.004824198041000569

# %%
cdc_main['pct_tot'] = cdc_main['Deaths']/cdc_main['Population']
cdc_main
# Out:
# <ipython-input-9-2ec0190d8883>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdc_main['pct_tot'] = cdc_main['Deaths']/cdc_main['Population']
#                     County  Deaths  Population   pct_tot      Years
# 0     Abbeville County, SC    1415      293313  0.004824  2018-2021
# 1        Acadia Parish, LA    3169      973764  0.003254  2018-2021
# 2      Accomack County, VA    1981      390636  0.005071  2018-2021
# 3           Ada County, ID   14385    13705181  0.001050  2018-2021
# 4         Adair County, IA     432       28815  0.014992  2018-2021
# ...                    ...     ...         ...       ...        ...
# 3134       Yuma County, AZ    7924     3402916  0.002329  2018-2021
# 3135       Yuma County, CO     403       40027  0.010068  2018-2021
# 3136     Zapata County, TX     462       56449  0.008184  2018-2021
# 3137     Zavala County, TX     521       45197  0.011527  2018-2021
# 3138    Ziebach County, SD      99       21068  0.004699  2018-2021
#
# [3139 rows x 5 columns]

# %%
col_names = ["County", "DrugOrAlc_Deaths", "Population", "DrugOrAlc_Deaths_pct", "Years"]
cdc_main.columns = col_names
cdc_main.head()
# Out:
#                  County  DrugOrAlc_Deaths  Population  DrugOrAlc_Deaths_pct  \
# 0  Abbeville County, SC              1415      293313              0.004824
# 1     Acadia Parish, LA              3169      973764              0.003254
# 2   Accomack County, VA              1981      390636              0.005071
# 3        Ada County, ID             14385    13705181              0.001050
# 4      Adair County, IA               432       28815              0.014992
#
#        Years
# 0  2018-2021
# 1  2018-2021
# 2  2018-2021
# 3  2018-2021
# 4  2018-2021
